# %%
# !pip install --user requests

# %%
import requests

url = 'http://www.ptt.cc/bbs/hotboards.html'

resp = requests.get(url)

print(resp.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>熱門看板 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/">批踢踢實業坊</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# ...

# %%
# !pip install --user --upgrade beautifulsoup4 lxml html5lib==1.0b8
# Out:
# Requirement already up-to-date: beautifulsoup4 in ./.local/lib/python3.5/site-packages
# Requirement already up-to-date: lxml in ./.local/lib/python3.5/site-packages
# Requirement already up-to-date: html5lib==1.0b8 in ./.local/lib/python3.5/site-packages
# Requirement already up-to-date: six in ./.local/lib/python3.5/site-packages (from html5lib==1.0b8)

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(resp.text.encode("utf-8"), "lxml")

print(soup.find('title'))
# Out:
# <title>熱門看板 - 批踢踢實業坊</title>

# %%
url = 'http://www.ptt.cc/bbs/Gossiping/'

resp = requests.get(url, cookies = {'over18': '1'})

print(resp.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# ...

# %%
soup = BeautifulSoup(resp.text.encode("utf-8"), "lxml")

gossip_list = soup.find('div', {'class': 'r-list-container action-bar-margin bbs-screen'})

link_list = gossip_list.find_all('a')
print(link_list)
# Out:
# [<a href="/bbs/Gossiping/M.1512628409.A.B82.html">[新聞] 郭台銘：川普重視勞工就業與薪資 美國投</a>, <a href="/bbs/Gossiping/M.1512628413.A.B7D.html">[問卦] 挖靠，這間露天咖啡廳妹子都不怕冷的</a>, <a href="/bbs/Gossiping/M.1512628469.A.CB1.html">Re: [新聞] 賴清德：《勞基法》不夠完善　將全面檢視</a>, <a href="/bbs/Gossiping/M.1512628480.A.C35.html">[問卦] 花音學校出現至今仍然逍遙法外的變態？</a>, <a href="/bbs/Gossiping/M.1512628531.A.33D.html">[新聞] 因一例一休6成勞工想兼職？其實只有11%</a>, <a href="/bbs/Gossiping/M.1512628533.A.75E.html">[問卦] 有沒有電鍋跑去做醫材的八卦?</a>, <a href="/bbs/Gossiping/M.1512628554.A.979.html">[新聞] 蔡英文力挺　賴清德預告勞基法還有下波</a>, <a href="/bbs/Gossiping/M.1512628568.A.4CC.html">Re: [新聞] 政院買廣告宣傳修勞基法 是因6成民眾</a>, <a href="/bbs/Gossiping/M.1512628668.A.7C1.html">[問卦] 畢業考主考官說只有一個人能畢業</a>, <a href="/bbs/Gossiping/M.1512628688.A.D48.html">Re: [問卦] 有沒有高雄義大國賠案的八卦？</a>, <a href="/bbs/Gossiping/M.1512628739.A.3A2.html">Re: [新聞] 日少女在校遭霸凌自殺　這張照片讓人看了</a>, <a href="/bbs/Gossiping/M.1512628780.A.A88.html">Re: [新聞] 賴揆：一例一休須立即修法 台灣需要先進</a>, <a href="/bbs/Gossiping/M.1512628790.A.028.html
# ...

# %%
print(link_list[0].get('href'))
# Out:
# /bbs/Gossiping/M.1512628409.A.B82.html

# %%
new_list = []

for i in range(len(link_list)):
    new_list.append(link_list[i].get('href'))
    
print(new_list)
# Out:
# ['/bbs/Gossiping/M.1512628409.A.B82.html', '/bbs/Gossiping/M.1512628413.A.B7D.html', '/bbs/Gossiping/M.1512628469.A.CB1.html', '/bbs/Gossiping/M.1512628480.A.C35.html', '/bbs/Gossiping/M.1512628531.A.33D.html', '/bbs/Gossiping/M.1512628533.A.75E.html', '/bbs/Gossiping/M.1512628554.A.979.html', '/bbs/Gossiping/M.1512628568.A.4CC.html', '/bbs/Gossiping/M.1512628668.A.7C1.html', '/bbs/Gossiping/M.1512628688.A.D48.html', '/bbs/Gossiping/M.1512628739.A.3A2.html', '/bbs/Gossiping/M.1512628780.A.A88.html', '/bbs/Gossiping/M.1512628790.A.028.html', '/bbs/Gossiping/M.1510415718.A.D77.html', '/bbs/Gossiping/M.1512306790.A.A21.html', '/bbs/Gossiping/M.1512469417.A.3E3.html', '/bbs/Gossiping/M.1512498602.A.CB6.html', '/bbs/Gossiping/M.1512057611.A.16B.html']

# %%
link_list = [link.get('href') for link in link_list]
print(link_list)
# Out:
# ['/bbs/Gossiping/M.1512628409.A.B82.html', '/bbs/Gossiping/M.1512628413.A.B7D.html', '/bbs/Gossiping/M.1512628469.A.CB1.html', '/bbs/Gossiping/M.1512628480.A.C35.html', '/bbs/Gossiping/M.1512628531.A.33D.html', '/bbs/Gossiping/M.1512628533.A.75E.html', '/bbs/Gossiping/M.1512628554.A.979.html', '/bbs/Gossiping/M.1512628568.A.4CC.html', '/bbs/Gossiping/M.1512628668.A.7C1.html', '/bbs/Gossiping/M.1512628688.A.D48.html', '/bbs/Gossiping/M.1512628739.A.3A2.html', '/bbs/Gossiping/M.1512628780.A.A88.html', '/bbs/Gossiping/M.1512628790.A.028.html', '/bbs/Gossiping/M.1510415718.A.D77.html', '/bbs/Gossiping/M.1512306790.A.A21.html', '/bbs/Gossiping/M.1512469417.A.3E3.html', '/bbs/Gossiping/M.1512498602.A.CB6.html', '/bbs/Gossiping/M.1512057611.A.16B.html']

# %%
def fetchPost(url):
    resp = requests.get('http://www.ptt.cc' + url, cookies = {'over18': '1'})
    
    soup = BeautifulSoup(resp.text.encode("utf-8"), "lxml")
    if soup.find('title'):
        title = soup.find('title').text
    else:
        title = None
        
    if soup.find('span', {'class': 'article-meta-value'}):
        author = soup.find('span', {'class': 'article-meta-value'}).text
    else:
        author = None
                 
    return{'title': title, 'author': author}
                 
post_list = [fetchPost(link) for link in link_list]
print(post_list)
# Out:
# [{'title': '[新聞] 郭台銘：川普重視勞工就業與薪資 美國投 - 看板 Gossiping - 批踢踢實業坊', 'author': 'sheepxo ((羊臣又))'}, {'title': '[問卦] 挖靠，這間露天咖啡廳妹子都不怕冷的(補圖 - 看板 Gossiping - 批踢踢實業坊', 'author': 'blackzero1 (瘦宅)'}, {'title': 'Re: [新聞] 賴清德：《勞基法》不夠完善\u3000將全面檢視 - 看板 Gossiping - 批踢踢實業坊', 'author': 'freeclouds (創造自己新的人生)'}, {'title': '[問卦] 花音學校出現至今仍然逍遙法外的變態？ - 看板 Gossiping - 批踢踢實業坊', 'author': 'leopika (龜山島田愛里壽)'}, {'title': '[新聞] 因一例一休6成勞工想兼職？其實只有11% - 看板 Gossiping - 批踢踢實業坊', 'author': 'jk182325 (萬里花我老婆)'}, {'title': '[問卦] 有沒有電鍋跑去做醫材的八卦? - 看板 Gossiping - 批踢踢實業坊', 'author': 'JeremyJoung (J.J.)'}, {'title': '[新聞] 蔡英文力挺\u3000賴清德預告勞基法還有下波 - 看板 Gossiping - 批踢踢實業坊', 'author': 'HTC92 (中国台湾人的驕傲-92共識)'}, {'title': 'Re: [新聞] 政院買廣告宣傳修勞基法 是因6成民眾 - 看板 Gossiping - 批踢踢實業坊', 'author': 'strike519 (噓我者 宅友也)'}, {'title': '[問卦] 畢業考主考官說只有一個人能畢業 - 看板 Gossiping - 批踢踢實業坊', 'author': 'meredith001 (蓮華我老婆￣▽￣)'}, {'title': 'Re: [問卦] 有沒有高雄義大國賠案的八卦？ - 看板 Gossiping - 批踢踢實業坊', 'author': 'wanz1995 (丸子)'}, {'title': 'Re: [新聞] 日少女在校遭霸凌自殺\u3000這張照片讓人
# ...

# %%
a = {}
print(type(a))
# Out:
# <class 'dict'>

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.ptt.cc/bbs/Gossiping/'

for i in range(5):
    resp = requests.get(url, cookies = {'over18': '1'})
    #print(resp.text)

    soup = BeautifulSoup(resp.text.encode("utf-8"), "lxml")

    gossip_list = soup.find('div', {'class': 'r-list-container action-bar-margin bbs-screen'})

    link_list = gossip_list.find_all('a')
    link_list = [link.get('href') for link in link_list]
    #print(link_list)

    paging_group = soup.find('div', {'class': 'btn-group btn-group-paging'})
    p_link = paging_group.find_all('a')
    p_link = p_link[1].get('href')
    print("Page " + (str)(i+1) + " list :")
    print(link_list)
    url = 'http://www.ptt.cc' + p_link
# Out:
# Page 1 list :
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.ptt.cc/bbs/Gossiping/'
html_list = []

def fetchPost(url):
    resp = requests.get(url, cookies = {'over18': '1'})
    
    soup = BeautifulSoup(resp.text.encode("utf-8"), "lxml")

    gossip_list = soup.find('div', {'class': 'r-list-container action-bar-margin bbs-screen'})

    link_list = gossip_list.find_all('a')
    
    for i in range(len(link_list)):
        html_list.append(link_list[i].get('href'))

    link_list = [link.get('href') for link in link_list]
    
    paging_group = soup.find('div', {'class': 'btn-group btn-group-paging'})
    p_link = paging_group.find_all('a')
    p_link = p_link[1].get('href')
    
    return 'http://www.ptt.cc' + p_link
    

for i in range(5):
    url = fetchPost(url)
    print("Page " + (str)(i+1) + " list :")
    print(link_list)

print('Whole html list is :')
print(html_list)
# Out:
# Page 1 list :
# ['/bbs/Gossiping/M.1513228742.A.110.html', '/bbs/Gossiping/M.1513228744.A.29F.html', '/bbs/Gossiping/M.1513228758.A.5A2.html', '/bbs/Gossiping/M.1513228775.A.30E.html', '/bbs/Gossiping/M.1513228779.A.7FB.html', '/bbs/Gossiping/M.1513228783.A.A7F.html', '/bbs/Gossiping/M.1513228786.A.992.html', '/bbs/Gossiping/M.1513228808.A.52B.html', '/bbs/Gossiping/M.1513228841.A.BFF.html', '/bbs/Gossiping/M.1513228864.A.91E.html', '/bbs/Gossiping/M.1513228880.A.6FC.html', '/bbs/Gossiping/M.1513228890.A.0A2.html', '/bbs/Gossiping/M.1513228897.A.6D4.html', '/bbs/Gossiping/M.1513228906.A.D30.html', '/bbs/Gossiping/M.1513228917.A.FD5.html', '/bbs/Gossiping/M.1513228930.A.17C.html', '/bbs/Gossiping/M.1513228950.A.C2D.html', '/bbs/Gossiping/M.1513229005.A.9EC.html', '/bbs/Gossiping/M.1513229054.A.466.html', '/bbs/Gossiping/M.1513229127.A.746.html']
# Page 2 list :
# ...

# %%
import os
import json
import requests
from uuid import uuid4
from bs4 import BeautifulSoup

class PttCrawler:
    
    def __init__(self, board, page, write=False):
        self.ptt_url = 'http://www.ptt.cc'
        self.board = board
        self.page = page
        
        self.session = requests.Session()
        self.session.cookies.update({
            'over18': '1'
        })
        
        self.write=write
        
    def run(self):
        url = self.ptt_url + '/bbs/' + self.board
        post_link_list = self.fetchPostLinkList(url)
        post_list = [self.fetchPost(post_link) for post_link in post_link_list]
#        if self.write:
#            result_dir = os.path.join('ptt_crawler/', str(uuid4()))
#            os.makefirs(result_dir, exist_ok=True)
#            
#            for post in post_list:
#                with open(os.path.join(result_dir, post['id']), 'w') as f:
#                    f.write(json.dumps(post, indent= 4))
        
        return post_list
    
    def fetchPostLinkList(self, url):
        if not url.startswith('http'):
            url = self.ptt_url + url
            
        html_list = []
        
        resp = self.session.get(url)
        
        soup = BeautifulSoup(resp.text.encode("utf-8"), "lxml")
        gossip_list = soup.find('div', {'class': 'r-list-container action-bar-margin bbs-screen'})
        
        link_list = gossip_list.find_all('a')
        for i in range(len(link_list)):
            html_list.append('http://www.ptt.cc' + link_list[i].get('href'))
#        html_list = [link.get('href') for link in link_list]
        
        if self.page > 1:
            for p in range(self.page - 1):
                paging_group = soup.find('div', {'class': 'btn-group btn-group-paging'})
                p_link = paging_group.find_all('a')
                p_link = p_link[1].get('href')
                new_url = 'http://www.ptt.cc' + p_link
            
                resp = self.session.get(new_url)
                soup = BeautifulSoup(resp.text.encode("utf-8"), "lxml")
                gossip_list = soup.find('div', {'class': 'r-list-container action-bar-margin bbs-screen'})
                link_list = gossip_list.find_all('a')
                
                for i in range(len(link_list)):
                    html_list.append('http://www.ptt.cc' + link_list[i].get('href'))
            
#        return 'http://www.ptt.cc' + p_link
        return html_list
    
    def fetchPost(self, url):
        resp = self.session.get(url)
        soup = BeautifulSoup(resp.text.encode("utf-8"), "lxml")

        if soup.find('div', {'class': 'article-metaline'}):
            metaline = soup.find_all('div',{'class': 'article-metaline'})
            author = metaline[0].text
            title = metaline[1].text
            date = metaline[2].text
            content = metaline[2].next_sibling.strip()
        else:
            author = None
            title = None
            date = None
            content = None
            
                 
        return{'title': title, 'author': author, 'date': date, 'content': content}

# %%
board = 'Gossiping'
page = 1

crawler = PttCrawler(board, page)
result = crawler.run()
print(result)
# Out:
# [{'content': '', 'date': '時間Thu Dec 21 15:55:38 2017', 'author': '作者micrub9314 (endless love)', 'title': '標題Re: [新聞] 高雄低薪環境嚴重 網友嘆：住高雄的大學'}, {'content': '雖然警察為民服務是好事啦\n\n不過最近這種新聞也太多了吧？\n\n政府每個月花6.7萬養警察，應該是拿去做更有意義的是事吧？\n\n這些人是不是連救護車錢都想省，乾脆打給免費的警車啊？\n\n\n\n有八卦嗎？\n\n--', 'date': '時間Thu Dec 21 15:55:53 2017', 'author': '作者bingodo (恐龍妹騎士)', 'title': '標題Re: [新聞] 阮某要生了！\u3000警車開道護送\u3000孕婦車上?1'}, {'content': '肥宅 我剩下一個月就要考試了\n\n可是 書還沒念完\n\n又念不下去QQ\n\n到底該怎麼辦...\n\nU 人可以教我怎麼收心ㄇ\n\n--', 'date': '時間Thu Dec 21 15:56:00 2017', 'author': '作者newup (我們沒有翅膀)', 'title': '標題[問卦] 念不下書怎麼半'}, {'content': '想請問各位大大\n\nPtt發幻想文要怎麼發\n\n才能讓別人信以為真？\n\n有什麼發幻想文發得很逼真的技巧嗎？\n\n幻想文怎麼發才能不像幻想文？\n\n\n--', 'date': '時間Thu Dec 21 15:56:22 2017', 'author': '作者fawangching (Mr.peace)', 'title': '標題[問卦] 幻想文怎麼發才不像幻想文？'}, {'content': '之前台灣甲甲為了要參加肛肛好大遊行\n\n特別包車北上\n\n在車程中硬要司機認同肛肛好族群理念\n\n結果害的司機崩潰暴走\n\n而這輛車也被稱為裝甲車\n\n那請問如果有裝甲飛機出現\n\n會出現什麼狀況呢？\n\n如果剛好空服員和機師都換成正常性向的帥哥\n\n又會怎樣呢？\n\nend\n\n--', 'date': '時間Thu Dec 21 15:57:34 2017', 'autho
# ...
